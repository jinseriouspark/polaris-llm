# %% [markdown]
# <a href="https://colab.research.google.com/github/jinseriouspark/polaris-llm/blob/main/RoleLLM_dataset_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1qFBjdW3mzOEm-pD8O_uXQLY94fbuGf4zBsOV7MhIZao/edit#gid=1175656062

# %%
# !git lfs install
# !git clone https://huggingface.co/datasets/ZenMoore/RoleBench
# Out:
# Git LFS initialized.
# Cloning into 'RoleBench'...
# remote: Enumerating objects: 263, done.
# remote: Counting objects: 100% (259/259), done.
# remote: Compressing objects: 100% (259/259), done.
# remote: Total 263 (delta 12), reused 0 (delta 0), pack-reused 4 (from 1)
# Receiving objects: 100% (263/263), 20.89 MiB | 5.23 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# Updating files: 100% (230/230), done.
# Filtering content: 100% (8/8), 366.76 MiB | 43.50 MiB/s, done.

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.5 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset
dataset = load_dataset('ZenMoore/RoleBench')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# ---------------------------------------------------------------------------
# CastError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in _prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, job_id)
#    2010                     try:
# -> 2011                         writer.write_table(table)
# ...

# %%
# !pip install jsonlines

# %%
import json
import jsonlines


role_g_baseline =[]
question_g_baseline = []
generalization_g_baseline = []
with jsonlines.open('/content/RoleBench/rolebench-eng/instruction-generalization/general/rolegpt_baseline.jsonl',) as json_file:

  for line in json_file.iter():
    role_g_baseline.append(line['role'])
    if line['role'] == 'Abraham Lincoln':
      question_g_baseline.append(line['question'])
      generalization_g_baseline.append(line['generated'])


role_g_train =[]
question_g_train = []
generalization_g_train = []
with jsonlines.open('/content/RoleBench/rolebench-eng/instruction-generalization/general/train.jsonl',) as json_file:

  for line in json_file.iter():
    role_g_train.append(line['role'])
    if line['role'] == 'Abraham Lincoln':
      question_g_train.append(line['question'])
      generalization_g_train.append(line['generated'])


role_g_test =[]
question_g_test = []
generalization_g_test = []
with jsonlines.open('/content/RoleBench/rolebench-eng/instruction-generalization/general/test.jsonl',) as json_file:

  for line in json_file.iter():
    role_g_test.append(line['role'])
    if line['role'] == 'Jack Sparrow':
      question_g_test.append(line['question'])
      generalization_g_test.append(line['generated'])

# %%
import json
import jsonlines


role_s_baseline =[]
question_s_baseline = []
generalization_s_baseline = []
with jsonlines.open('/content/RoleBench/rolebench-eng/instruction-generalization/role_specific/rolegpt_baseline.jsonl',) as json_file:

  for line in json_file.iter():
    role_s_baseline.append(line['role'])
    if line['role'] == 'Abraham Lincoln':
      question_s_baseline.append(line['question'])
      generalization_s_baseline.append(line['generated'])


role_s_train =[]
question_s_train = []
generalization_s_train = []
with jsonlines.open('/content/RoleBench/rolebench-eng/instruction-generalization/role_specific/train.jsonl',) as json_file:

  for line in json_file.iter():
    role_s_train.append(line['role'])
    if line['role'] == 'Abraham Lincoln':
      question_s_train.append(line['question'])
      generalization_s_train.append(line['generated'])


role_s_test =[]
question_s_test = []
generalization_s_test = []
with jsonlines.open('/content/RoleBench/rolebench-eng/instruction-generalization/role_specific/test.jsonl',) as json_file:

  for line in json_file.iter():
    role_s_test.append(line['role'])
    if line['role'] == 'Jack Sparrow':
      question_s_test.append(line['question'])
      generalization_s_test.append(line['generated'])

# %%
generalization_s_test[:10]
# Out:
# [[" Ah, well, you see, I always have a few tricks up my sleeve, or in this case, up my coffin. It wasn't easy, though, as I had to wait for just the right moment to break open the casket without drawing too much attention to myself. But, as they say, desperate times call for desperate measures, and I've always been good at thinking on my feet."],
#  [" Aha! Now, that's a clever question. You see, the compass is no ordinary compass. It points to what you want most in the world...sometimes. It's a tricky thing, that compass, but I've learned to read it like a book. When I learned about the key to Davy Jones' locker, I knew the compass would be the key to finding it."],
#  [' Our journey upriver was to find the heart of Davy Jones, as it was the only way to free me from my debt to him while also preventing him from obtaining the heart to control the seas.'],
# ...

# %%
import json
import jsonlines


role_g_baseline =[]
question_g_baseline = []
generalization_g_baseline = []
with jsonlines.open('/content/RoleBench/rolebench-eng/role-generalization/general/rolegpt_baseline.jsonl',) as json_file:

  for line in json_file.iter():
    role_g_baseline.append(line['role'])
    if line['role'] == 'Abraham Lincoln':
      question_g_baseline.append(line['question'])
      generalization_g_baseline.append(line['generated'])


role_g_train =[]
question_g_train = []
generalization_g_train = []
with jsonlines.open('/content/RoleBench/rolebench-eng/role-generalization/general/train.jsonl',) as json_file:

  for line in json_file.iter():
    role_g_train.append(line['role'])
    if line['role'] == 'Abraham Lincoln':
      question_g_train.append(line['question'])
      generalization_g_train.append(line['generated'])


role_g_test =[]
question_g_test = []
generalization_g_test = []
with jsonlines.open('/content/RoleBench/rolebench-eng/role-generalization/general/test.jsonl',) as json_file:

  for line in json_file.iter():
    role_g_test.append(line['role'])
    if line['role'] == 'Jack Sparrow':
      question_g_test.append(line['question'])
      generalization_g_test.append(line['generated'])

# %%
import json
import jsonlines


role_s_baseline =[]
question_s_baseline = []
generalization_s_baseline = []
with jsonlines.open('/content/RoleBench/rolebench-eng/role-generalization/role_specific/rolegpt_baseline.jsonl',) as json_file:

  for line in json_file.iter():
    role_s_baseline.append(line['role'])
    if line['role'] == 'Abraham Lincoln':
      question_s_baseline.append(line['question'])
      generalization_s_baseline.append(line['generated'])


role_s_train =[]
question_s_train = []
generalization_s_train = []
with jsonlines.open('/content/RoleBench/rolebench-eng/role-generalization/role_specific/train.jsonl',) as json_file:

  for line in json_file.iter():
    role_s_train.append(line['role'])
    if line['role'] == 'Abraham Lincoln':
      question_s_train.append(line['question'])
      generalization_s_train.append(line['generated'])


role_s_test =[]
question_s_test = []
generalization_s_test = []
with jsonlines.open('/content/RoleBench/rolebench-eng/role-generalization/role_specific/test.jsonl',) as json_file:

  for line in json_file.iter():
    role_s_test.append(line['role'])
    if line['role'] == 'Jack Sparrow':
      question_s_test.append(line['question'])
      generalization_s_test.append(line['generated'])

# %%
generalization_s_test[:10]
# Out:
# [["Ah, well, you see, I always have a few tricks up my sleeve, or in this case, up my coffin. It wasn't easy, though, as I had to wait for just the right moment to break open the casket without drawing too much attention to myself. But, as they say, desperate times call for desperate measures, and I've always been good at thinking on my feet."],
#  ["That's a tricky question, mate. After all, I've had many enemies over the years, and I wouldn't want to offend any of them by playing favorites. But if I had to pick one, I suppose I might say Captain Barbossa. We have a long history together, and though we may not see eye-to-eye on everything, there's a certain respect that comes from going head-to-head with someone as cunning and resourceful as he is."],
# ...
